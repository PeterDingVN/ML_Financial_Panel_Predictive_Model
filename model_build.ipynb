# %% [markdown]
# # Load data + libs

# %%
# Import libs
from utils import *
from utils.ml_hyperpars import lrg, xgb_class, \
    r2, rmse, mape, \
    accuracy, roc_auc, precision, recall, \
    classification_report

# Load data
df_revenue = pd.read_csv('data_for_modelling/df_revenue.csv')
df_ebitda = pd.read_csv('data_for_modelling/df_ebitda.csv')
df_roa = pd.read_csv('data_for_modelling/df_roa.csv')
df_roe = pd.read_csv('data_for_modelling/df_roe.csv')
df_roic = pd.read_csv('data_for_modelling/df_roic.csv')
df_roce = pd.read_csv('data_for_modelling/df_roce.csv')
df_value = pd.read_csv('data_for_modelling/df_value_ad.csv')

# %% [markdown]
# # Modelling

# %% [markdown]
# Data

# %%
# Make input - test set
revenue_input, revenue_test = input_test_split(df_revenue)
roa_input, roa_test = input_test_split(df_roa)
roe_input, roe_test = input_test_split(df_roe)
roic_input, roic_test = input_test_split(df_roic)
roce_input, roce_test = input_test_split(df_roce)

value_input, value_test = input_test_split(df_value)
ebitda_input, ebitda_test = input_test_split(df_ebitda)

# %% [markdown]
# Modelling

# %%
# Revenue

# Hyper-param + model choice
revenue_obj = InputData(revenue_input, 'company', 'year', 'revenue', reg=True)
display(revenue_obj.optimal_param(n_splits=3, test_size=2))

# Train val
X_train, y_train, X_val, y_val = train_val_split(revenue_input, 'revenue')
model = lrg(fit_intercept=True)
model.fit(X_train, y_train)
y_pred = model.predict(X_val)

print('----------- TRAIN RESULTS -----------')
print(f'R2: {r2(y_pred, y_val)}')
print(f'RMSE: {rmse(y_pred, y_val)}')
print(f'MAPE: {mape(y_pred, y_val)}')
# Test
print('----------- TEST RESULTS -----------')
X_test = revenue_test.drop(['company', 'revenue', 'year'], axis=1)
y_test = revenue_test['revenue']
y_pred_test = model.predict(X_test)
print(f'R2: {r2(y_pred_test, y_test)}')
print(f'RMSE: {rmse(y_pred_test, y_test)}')
print(f'MAPE: {mape(y_pred_test, y_test)}')
# Out:
# Processing XG_reg ...
# Processing Linear_reg ...
#     algo_used                                             params  \
# 7  Linear_reg                           {'fit_intercept': False}
# 6  Linear_reg                            {'fit_intercept': True}
# 0      XG_reg  {'learning_rate': 0.05, 'max_depth': 8, 'n_est...
# 4      XG_reg  {'learning_rate': 0.03, 'max_depth': 8, 'n_est...
# 5      XG_reg  {'learning_rate': 0.03, 'max_depth': 8, 'n_est...
# 1      XG_reg  {'learning_rate': 0.05, 'max_depth': 8, 'n_est...
# 2      XG_reg  {'learning_rate': 0.05, 'max_depth': 8, 'n_est...
# 3      XG_reg  {'learning_rate': 0.03, 'max_depth': 8, 'n_est...
#
#    mean_test_r2  mean_test_mape  mean_test_rmse
# 7      0.914456        0.012553        0.569842
# 6      0.914036        0.012749        0.571233
# 0      0.907331        0.013537        0.593050
# 4      0.906996        0.013553        0.594216
# 5      0.906342        0.013689        0.596333
# 1      0.906250        0.013743        0.596654
# 2      0.905204        0.013921        0.599998
# 3      0.902434        0.014009        0.608339
# ----------- TRAIN RESULTS -----------
# R2: 0.9044978091299306
# RMSE: 0.601895303996183
# MAPE: 0.012731403722221023
# ----------- TEST RESULTS -----------
# R2: 0.9215238827698281
# RMSE: 0.5478324216147226
# MAPE: 0.010842666730429688

# %%
# Value_add

# Hyper-param + model choice
value_obj = InputData(value_input, 'company', 'year', 'value_add', reg=False)
display(value_obj.optimal_param(n_splits=3, test_size=2))

# Train val
X_train, y_train, X_val, y_val = train_val_split(value_input, 'value_add')
model = xgb_class(n_estimators= 200, learning_rate=0.02, max_depth=10,
                subsample=0.5, scale_pos_weight=0.223
                  )
model.fit(X_train, y_train)
y_pred = model.predict(X_val)


print('----------- TRAIN RESULTS -----------')
print(f'Accuracy: {accuracy(y_pred, y_val)}')
print(f'Precision: {precision(y_pred, y_val)}')
print(f'Recall: {recall(y_pred, y_val)}')
print(f'ROC_AUC: {roc_auc(y_pred, y_val)}')
# Test
print('----------- TEST RESULTS -----------')
X_test = value_test.drop(['company', 'value_add', 'year'], axis=1)
y_test = value_test['value_add']
y_pred_test = model.predict(X_test)
print(f'Accuracy: {accuracy(y_pred_test, y_test)}')
print(f'Precision: {precision(y_pred_test, y_test)}')
print(f'Recall: {recall(y_pred_test, y_test)}')
print(f'ROC_AUC: {roc_auc(y_pred_test, y_test)}')

print(classification_report(y_val, y_pred, digits=3))
# Out:
# Processing XG_class ...
# Processing KNN_class ...
#     algo_used                                             params  \
# 20   XG_class  {'learning_rate': 0.03, 'max_depth': 10, 'n_es...
# 2    XG_class  {'learning_rate': 0.05, 'max_depth': 5, 'n_est...
# 14   XG_class  {'learning_rate': 0.03, 'max_depth': 5, 'n_est...
# 5    XG_class  {'learning_rate': 0.05, 'max_depth': 5, 'n_est...
# 23   XG_class  {'learning_rate': 0.03, 'max_depth': 10, 'n_es...
# 17   XG_class  {'learning_rate': 0.03, 'max_depth': 5, 'n_est...
# 10   XG_class  {'learning_rate': 0.05, 'max_depth': 10, 'n_es...
# 7    XG_class  {'learning_rate': 0.05, 'max_depth': 10, 'n_es...
# 8    XG_class  {'learning_rate': 0.05, 'max_depth': 10, 'n_es...
# 22   XG_class  {'learning_rate': 0.03, 'max_depth': 10, 'n_es...
# 19   XG_class  {'learning_rate': 0.03, 'max_depth': 10, 'n_es...
# 1    XG_class  {'learning_rate': 0.05, 'max_depth': 5, 'n_est...
# 16   XG_class  {'learning_rate': 0.03, 'max_depth': 5, 'n_est...
# 11   XG_class  {'learning_rate': 0.05, 'max_depth': 10, 'n_es...
# 13   XG_class  {'learning_rate': 0.03, 'max_depth': 5, 'n_est...
# 4    XG_class  {'learning_rate': 0.05, 'max_depth': 5, 'n_est...
# 21   XG_class  {'learning_rate': 0.03, 'max_depth': 10, 'n_es...
# 9    XG_class  {'learning_rate': 0.05, 'max_depth': 10, 'n_es...
# 6    XG_class  {'learning_rate': 0.05, 'max_depth': 10, 'n_es...
# 18   XG_class  {'learning_rate': 0.03, 'max_depth': 10, 'n_es...
# 15   XG_class  {'learning_rate': 0.03, 'max_depth': 5, 'n_est...
# 0    XG_class  {'learning_rate': 0.05, 'max_depth': 5, 'n_est...
# 12   XG_class  {'learning_rate': 0.03, 'max_depth': 5, 'n_est...
# 3    XG_class  {'learning_rate': 0.05, 'max_depth': 5, 'n_est...
# 24  KNN_class           {'n_neighbors': 1, 'weights': 'uniform'}
# 25  KNN_class          {'n_neighbors': 1, 'weights': 'distance'}
# 27  KNN_class          {'n_neighbors': 3, 'weights': 'distance'}
# 29  KNN_class          {'n_neighbors': 5, 'weights': 'distance'}
# 26  KNN_class           {'n_neighbors': 3, 'weights': 'uniform'}
# 31  KNN_class          {'n_neighbors': 7, 'weights': 'distance'}
# 33  KNN_class          {'n_neighbors': 9, 'weights': 'distance'}
# 28  KNN_class           {'n_neighbors': 5, 'weights': 'uniform'}
# 30  KNN_class           {'n_neighbors': 7, 'weights': 'uniform'}
# 32  KNN_class           {'n_neighbors': 9, 'weights': 'uniform'}
#
#     mean_test_accuracy  mean_test_roc_auc  mean_test_precision  \
# 20            0.777431           0.777431             0.911312
# 2             0.776972           0.776972             0.911659
# 14            0.776823           0.776823             0.911153
# 5             0.776787           0.776787             0.912213
# 23            0.776778           0.776778             0.911530
# 17            0.776737           0.776737             0.911577
# 10            0.776724           0.776724             0.912996
# 7             0.776717           0.776717             0.912807
# 8             0.776492           0.776492             0.911416
# 22            0.776426           0.776426             0.912523
# 19            0.776332           0.776332             0.912237
# 1             0.775361           0.775361             0.913161
# 16            0.775156           0.775156             0.913096
# 11            0.775113           0.775113             0.911254
# 13            0.774653           0.774653             0.911850
# 4             0.772717           0.772717             0.913258
# 21            0.771621           0.771621             0.914834
# 9             0.771615           0.771615             0.914417
# 6             0.771505           0.771505             0.915503
# 18            0.770282           0.770282             0.915596
# 15            0.766293           0.766293             0.918602
# 0             0.763544           0.763544             0.918251
# 12            0.762643           0.762643             0.917398
# 3             0.762146           0.762146             0.916131
# 24            0.591823           0.591823             0.839826
# 25            0.591823           0.591823             0.839826
# 27            0.576165           0.576165             0.832259
# 29            0.570333           0.570333             0.829558
# 26            0.566744           0.566744             0.828664
# 31            0.560485           0.560485             0.825862
# 33            0.554231           0.554231             0.823497
# 28            0.549694           0.549694             0.822421
# 30            0.541548           0.541548             0.819362
# 32            0.531758           0.531758             0.816105
#
#     mean_test_recall
# 20          0.925630
# 2           0.921493
# 14          0.925006
# 5           0.916147
# 23          0.921616
# 17          0.920922
# 10          0.910286
# 7           0.911305
# 8           0.921626
# 22          0.913152
# 19          0.915170
# 1           0.904360
# 16          0.904031
# 11          0.918316
# 13          0.912234
# 4           0.894933
# 21          0.880076
# 9           0.883975
# 6           0.875854
# 18          0.870771
# 15          0.838879
# 0           0.833430
# 12          0.836415
# 3           0.840860
# 24          0.870612
# 25          0.870612
# 27          0.921982
# 29          0.945229
# 26          0.926927
# 31          0.962098
# 33          0.969875
# 28          0.949141
# 30          0.966663
# 32          0.973297
# ----------- TRAIN RESULTS -----------
# Accuracy: 0.8234170524029945
# Precision: 0.9417391304347826
# Recall: 0.8819218241042345
# ROC_AUC: 0.8234170524029943
# ----------- TEST RESULTS -----------
# Accuracy: 0.8013917363191925
# Precision: 0.901541095890411
# Recall: 0.9410187667560321
# ROC_AUC: 0.8013917363191926
#               precision    recall  f1-score   support
#
#            0      0.765     0.601     0.673       363
#            1      0.882     0.942     0.911      1150
#
#     accuracy                          0.860      1513
#    macro avg      0.823     0.771     0.792      1513
# weighted avg      0.854     0.860     0.854      1513

# %%
# Ebitda

# # Hyper-param + model choice
# ebitda_obj = InputData(ebitda_input, 'company', 'year', 'ebitda', reg=False)
# display(ebitda_obj.optimal_param(n_splits=3, test_size=2))

# Train val
X_train, y_train, X_val, y_val = train_val_split(ebitda_input, 'ebitda')
model = xgb_class(n_estimators= 300, learning_rate=0.03, max_depth=15,
                subsample=0.7, scale_pos_weight= 0.15134
                  )
model.fit(X_train, y_train)
y_pred = model.predict(X_val)


print('----------- TRAIN RESULTS -----------')
print(f'Accuracy: {accuracy(y_pred, y_val)}')
print(f'Precision: {precision(y_pred, y_val)}')
print(f'Recall: {recall(y_pred, y_val)}')
print(f'ROC_AUC: {roc_auc(y_pred, y_val)}')
# Test
print('----------- TEST RESULTS -----------')
X_test = ebitda_test.drop(['company', 'ebitda', 'year'], axis=1)
y_test = ebitda_test['ebitda']
y_pred_test = model.predict(X_test)
print(f'Accuracy: {accuracy(y_pred_test, y_test)}')
print(f'Precision: {precision(y_pred_test, y_test)}')
print(f'Recall: {recall(y_pred_test, y_test)}')
print(f'ROC_AUC: {roc_auc(y_pred_test, y_test)}')

print(classification_report(y_val, y_pred, digits=3))
# Out:
# ----------- TRAIN RESULTS -----------
# Accuracy: 0.7966333967046895
# Precision: 0.9388544891640866
# Recall: 0.9224334600760457
# ROC_AUC: 0.7966333967046895
# ----------- TEST RESULTS -----------
# Accuracy: 0.7469932043722134
# Precision: 0.9034749034749034
# Recall: 0.9535452322738386
# ROC_AUC: 0.7469932043722134
#               precision    recall  f1-score   support
#
#            0      0.671     0.612     0.640       263
#            1      0.922     0.939     0.931      1292
#
#     accuracy                          0.884      1555
#    macro avg      0.797     0.776     0.785      1555
# weighted avg      0.880     0.884     0.881      1555
